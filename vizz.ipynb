# %%
from baselines.common import plot_util as pu
import matplotlib.pyplot as plt
import numpy as np

# %%
results_orig = pu.load_results('logs/test')
# Out:
# /Users/sophiasun/Desktop/2cool4school/dev/baselines/baselines/bench/monitor.py:163: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.headers = headers # HACK to preserve backwards compatibility

# %% [markdown]
# ## Original (var = 1 ->  0.3)

# %%
r_orig = results_orig[0]
plt.plot(np.cumsum(r_orig.monitor.l), r_orig.monitor.r)

# %%
plt.plot(np.cumsum(r_orig.monitor.l), pu.smooth(r_orig.monitor.r, radius=100))

# %% [markdown]
# ## Var = 0.1

# %%
results_01 = pu.load_results('logs/test0.1') 
r01 = results_01[0]
plt.plot(np.cumsum(r01.monitor.l), r01.monitor.r)

# %%
plt.plot(np.cumsum(r01.monitor.l), pu.smooth(r01.monitor.r, radius=100))

# %% [markdown]
# ## Var = 0.3

# %%
results_03 = pu.load_results('logs/trpo-var=0.3') 
r03 = results_03[0]
plt.plot(np.cumsum(r03.monitor.l), r03.monitor.r)

# %%
plt.plot(np.cumsum(r03.monitor.l), pu.smooth(r03.monitor.r, radius=100))

# %% [markdown]
# ## variance = 1.0

# %%
results_1 = pu.load_results('logs/test1.1')

# %%
r1 = results_1[0]
plt.plot(np.cumsum(r1.monitor.l), r1.monitor.r)

# %%
plt.plot(np.cumsum(r1.monitor.l), pu.smooth(r1.monitor.r, radius=100))

# %% [markdown]
# # hopper

# %%
results_h = pu.load_results('logs/hopper')

# %%
r_h = results_h[0]
plt.plot(np.cumsum(r_h.monitor.l), r_h.monitor.r)

# %%
plt.plot(np.cumsum(r_h.monitor.l), pu.smooth(r_h.monitor.r, radius=100))

# %% [markdown]
# ## var = 0.1

# %%
results_h01 = pu.load_results('logs/hopper0.1')

# %%
rh01 = results_h01[0]
plt.plot(np.cumsum(rh01.monitor.l), rh01.monitor.r)

# %%
plt.plot(np.cumsum(rh01.monitor.l), pu.smooth(rh01.monitor.r, radius=100))

# %% [markdown]
# ## var = 1.0

# %%
results_h1 = pu.load_results('logs/hopper1')

# %%
rh1 = results_h1[0]
plt.plot(np.cumsum(rh1.monitor.l), rh1.monitor.r)

# %%
plt.plot(np.cumsum(rh1.monitor.l), pu.smooth(rh1.monitor.r, radius=100))
